# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# You’re asking the classic tongue‑twister, and it’s also become a bit of a pop‑culture science trivia.
# The folkloric “answer” goes like this:
#
# > **A woodchuck would chuck as much wood as a woodchuck could,**
# > **but if you tried to figure it out in real numbers, you’d get about 700 pounds (≈0.32 t) of wood—or roughly 0.5 cubic meters,**
# > **roughly the volume of a small shed.**
#
# The 1974 “field study” by wildlife biologist Richard Thomas, who measured the burrowing habits of woodchucks, estimated they moved about 700 lb of dirt per burrow. Translating that to “chucked wood” gave the popular 700‑pound figure – pure tongue‑twister math!
#
# **Bottom line:** If a woodchuck could chuck wood, it’d chuck enough to fill a stubby bedroom closet. And if it tried to do more, the mistake would be in the “chuck” terminology—woodchucks *dig* more than they ever “chuck” anything at all.

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 14: A woodchuck would chuck as much wood as a woodchuck could ch...
# Response 4: A classic tongue‑twister, indeed! While the saying itself do...
# Response 10: If the universe were a playful rhyme, a woodchuck would chuc...
# Response 23: People usually answer with a playful one‑liners, but a littl...
# Response 22: **Answer – The Classic**
#
# "How much wood could a wood‑chuck ...
# Response 11: A wood‑chuck would chuck as much wood as a wood‑chuck could ...
# Response 12: Ah, the age‑old riddle that tickles the tongue and tickles t...
# Response 24: Sure!
# The classic answer goes:
#
# > **“A woodchuck would chu...
# Response 21: Ah, the age‑old question that has inspired countless recitat...
# Response 9: *A classic tongue‑twister that has been reality‑checked only...
# Response 6: A classic tongue‑twister has been turned into a bit of folk‑...
# Response 18: Nice—classic tongue‑twister!
# While real woodchucks (ground...
# Response 2: A woodchuck (groundhog) never actually chuckles wood – the “...
# Response 5: People usually answer with a bit of tongue‑in‑cheek humor: *...
# Response 13: Ah, the classic – an ever‑popular tongue‑twisting riddle tha...
# Response 8: The classic tongue‑twister itself doesn’t give us a strictly...
# Response 1: Ah, the classic tongue‑twister! 🎶
#
# **“How much wood would a ...
# Response 3: Sure thing, let’s dive into the classic “how much wood a woo...
# Response 15: (Answer:
# Once, in a sun‑baked plain edged by a slow‑moving...
# Response 16: **Answer:**
# If we take the classic tongue‑twister and run ...
# Response 7: In short, the classic answer is:
#
# > **“A woodchuck would chu...
# Response 19: **Answer (in classic tongue‑twister style):**
#
# *A woodchuc...
# Response 17: 🌲 **Woodchuck’s Wood‑Chucking Estimate** 🌲
#
# The classic qu...
# Response 20: **Answer (with a dash of science & a pinch of humor):**
#
# > “...
